# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

def sigmoid(x):
     g=1/(1+np.exp(-x))
     return g


x=np.linspace(-25,25,11)
y=sigmoid(x)

plt.plot(x,y)
plt.xlabel='Value'
plt.ylabel="Sigmoid"
plt.show()
