# %% [markdown]
# Using Closed_Form Equation

# %%
import numpy as np
np.random.seed(42)
m=100
X=2*np.random.rand(m,1)
Y=4+3*X+np.random.randn(m,1)

# %%
import matplotlib.pyplot as plt

plt.scatter(X,Y,s=20)
plt.show()

# %%
from sklearn.preprocessing import add_dummy_feature

X_b=add_dummy_feature(X)
theta_best=np.linalg.inv(X_b.T @ X_b) @ X_b.T @ Y
theta_best
# Out:
# array([[4.21509616],
#        [2.77011339]])

# %% [markdown]
# instead of       np.linalg.inv(X_b.T @ X_b) @ X_b.T
#       use      np.linalg.pinv(X_b)

# %%
X_new=np.array([[0],[2]])
X_new_b=add_dummy_feature(X_new)
Y_predict=X_new_b @ theta_best
Y_predict
# Out:
# array([[4.21509616],
#        [9.75532293]])

# %%
plt.scatter(X,Y,s=20)
plt.plot(X_new,Y_predict,'r')
plt.show()

# %% [markdown]
# Using Scikit Learn:-

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
lin_reg.intercept_,lin_reg.coef_
# Out:
# (array([4.21509616]), array([[2.77011339]]))

# %%
lin_reg.predict(X_new)
# Out:
# array([[4.21509616],
#        [9.75532293]])

# %%
import numpy as np
np.random.seed(42)
m=100
X=2*np.random.rand(m,1)
Y=4+3*X+np.random.randn(m,1)

import matplotlib.pyplot as plt
plt.scatter(X,Y,s=20)
plt.show()

from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X,Y)

X_new=np.array([[0],[2]])
Y_predict=lin_reg.predict(X_new)

plt.scatter(X,Y,s=20)
plt.plot(X_new,Y_predict,'r')
plt.show()

print(f"Predictions for {X_new} are {Y_predict}")
# Out:
# Predictions for [[0]
#  [2]] are [[4.21509616]
#  [9.75532293]]
